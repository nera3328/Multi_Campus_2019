# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('C:/Users/KMJ/Desktop/빅콘/유통데이터 (1)/GS리테일_동별 매출지수용 기준값 확인_AMT_NEW.xlsx',sheet_name='종합테이블')
data.head(5)

df_0=data.fillna(0)
df_0.head(5)
# Out:
#     OPER_DT  BOR_CD   ADMD_CD   AMT_IND  LCLS_10_P  LCLS_20_P  LCLS_30_P  \
# 0  20180401    1111  11110515  0.736933   0.279018   0.299569   0.334816
# 1  20180401    1111  11110530  1.258473   0.237403   0.257984   0.349826
# 2  20180401    1111  11110540  0.674164   0.254081   0.246844   0.324434
# 3  20180401    1111  11110550  1.010874   0.416368   0.217715   0.282613
# 4  20180401    1111  11110560  1.012942   0.311321   0.267387   0.262358
#
#    LCLS_40_P  LCLS_50_P  LCLS_60_P  LCLS_70_P  LCLS_80_P
# 0   0.015636   0.053782   0.000265   0.013092   0.003823
# 1   0.045502   0.092581   0.004988   0.002467   0.009250
# 2   0.065025   0.089691   0.000000   0.013212   0.006712
# 3   0.026738   0.036622   0.005893   0.012295   0.001756
# 4   0.014736   0.135350   0.000000   0.007270   0.001577

# %%
plt.figure(1, figsize=(50,50))
#plt.plot(df_0['AMT_IND'],linewidth=1,label="매출지수")
plt.plot(df_0['LCLS_10_P'],linewidth=1,label="meal").set_fontsize(10)
plt.plot(df_0['LCLS_20_P'],linewidth=1,label="snack").set_fontsize(10)
plt.plot(df_0['LCLS_30_P'],linewidth=1,label="beaverage").set_fontsize(10)
plt.plot(df_0['LCLS_40_P'],linewidth=1,label="home&living").set_fontsize(10)
plt.plot(df_0['LCLS_50_P'],linewidth=1,label="health&beauty").set_fontsize(10)
plt.plot(df_0['LCLS_60_P'],linewidth=1,label="hobby").set_fontsize(10).set_fontsize(10)
plt.plot(df_0['LCLS_70_P'],linewidth=1,label="social").set_fontsize(10).set_fontsize(10)
plt.plot(df_0['LCLS_80_P'],linewidth=1,label="pregnancy").set_fontsize(10)
plt.title("Non_NA_Total_LIST").set_fontsize(10)
plt.grid()
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-1bdff5afad78> in <module>
#       1 plt.figure(1, figsize=(50,50))
#       2 #plt.plot(df_0['AMT_IND'],linewidth=1,label="매출지수")
# ----> 3 plt.plot(df_0['LCLS_10_P'],linewidth=1,label="meal").set_fontsize(10)
#       4 plt.plot(df_0['LCLS_20_P'],linewidth=1,label="snack").set_fontsize(10)
#       5 plt.plot(df_0['LCLS_30_P'],linewidth=1,label="beaverage").set_fontsize(10)
#
# AttributeError: 'list' object has no attribute 'set_fontsize'

# %%
plt.figure(1, figsize=(50,30))
plt.plot(df_0['AMT_IND'],linewidth=1,label="매출지수")
plt.title("Non_NA_Total_LIST")
plt.grid()
plt.legend()
plt.show()
