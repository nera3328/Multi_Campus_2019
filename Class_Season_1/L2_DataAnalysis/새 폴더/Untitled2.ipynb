# %%
import requests

# %%
url='http://www.naver.com'

result= requests. get(url)
result.status_code
# Out:
# 200

# %%
result.text
# Out:
# '<!doctype html>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<html lang="ko">\n<head>\n<meta charset="utf-8">\n<meta name="Referrer" content="origin">\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=1100">\n<meta name="apple-mobile-web-app-title" content="NAVER" />\n<meta name="robots" content="index,nofollow"/>\n<meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>\n<meta property="og:title" content="네이버">\n<meta property="og:url" content="https://www.naver.com/">\n<meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png">\n<meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>\n<meta name="twitter:card" content="summary">\n<meta name="twitter:title" content="">\n<meta name="twitter:url" content="https://www.naver.com/">\n<meta name
# ...

# %%
search_url='http://search.naver.com/search.naver?=query='
url=search_url+'파이썬'
search=requests.get(url)
search.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content=" : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'\'의 네이버 통합검색 결과입니다."> <title> : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_140327.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_190523.css"> <link rel="stylesheet" type="text/css" href="https://ssl
# ...

# %%
search_url='http://search.naver.com/search.naver?query='
param={'query':'파이썬'}
search=requests.get(search_url,param)
search.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content=" : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'\'의 네이버 통합검색 결과입니다."> <title> : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_140327.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_190523.css"> <link rel="stylesheet" type="text/css" href="https://ssl
# ...

# %%
search.content
# Out:
# b'<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content=" : \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xed\x86\xb5\xed\x95\xa9\xea\xb2\x80\xec\x83\x89"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'\'\xec\x9d\x98 \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xed\x86\xb5\xed\x95\xa9\xea\xb2\x80\xec\x83\x89 \xea\xb2\xb0\xea\xb3\xbc\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4."> <meta name="description" lang="ko" content="\'\'\xec\x9d\x98 \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xed\x86\xb5\xed\x95\xa9\xea\xb2\x80\xec\x83\x89 \xea\xb2\xb0\xea\xb3\xbc\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4."> <title> : \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xed\x86\xb5\xed\x95\xa9\xea\xb2\x80\xec\x83
# ...

# %%
type(search.text),type(search.content)
# Out:
# (str, bytes)

# %%
search.url
# Out:
# 'https://search.naver.com/search.naver?=query=%ED%8C%8C%EC%9D%B4%EC%8D%AC'

# %%
search.encoding
# Out:
# 'UTF-8'

# %%
search.headers
# Out:
# {'Date': 'Wed, 12 Jun 2019 04:14:16 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': 'page_uid=Udt8bsp0JXossT/edYZssssstvd-267822; path=/; domain=.naver.com, _naver_usersession_=S5qLX734QBMMVbMeGxlsCQ==; path=/; expires=Wed, 12-Jun-19 04:19:16 GMT; domain=.naver.com, nx_ssl=2; Domain=.naver.com; Path=/; Expires=Fri, 12-Jul-2019 04:14:16 GMT;', 'X-Frame-Options': 'SAMEORIGIN', 'X-XSS-Protection': '1; report=/p/er/post/xss', 'Cache-Control': 'no-cache, no-store, must-revalidate, max-age=0', 'Pragma': 'no-cache', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Server': 'nxg'}

# %%
from bs4 import BeautifulSoup

# %%
search_url='http://search.naver.com/search.naver'

keyword='정상회담'

param={'where':'news','query':keyword}

result=requests.get(search_url,param)
result.status_code
# Out:
# 200

# %%
Soup=BeautifulSoup(result.content,'lxml')

# %%
ul_contents=Soup.find('ul',class_='type01')
len(ul_contents.contents)
# Out:
# 21

# %%
now_ul = []
Count = 0

for u in ul_contents.contents:
    if not str(u).strip():
        continue
    now_ul.append(u)
    
    Count += 1
    print(count, now_ul)
# Out:
# 10 [<li id="sp_nws1"> <div class="thumb"><a class="sp_thmb thmb80" href="http://www.newsis.com/view/?id=NISX20190612_0000678058&amp;cID=10101&amp;pID=10100" onclick="return goOtherCR(this, 'a=nws*h.img&amp;r=1&amp;i=88000127_000000000000000009280974&amp;g=003.0009280974&amp;u='+urlencode(this.href));" target="_blank"><img alt='볼턴 "3차 북미정상회' class="" height="80" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F003%2F2019%2F06%2F12%2F9280974.jpg&amp;type=ofullfill80_80_q75_re2" width="80"/><span class="thmb_v"></span></a></div> <dl> <dt><a class="_sp_each_title" href="http://www.newsis.com/view/?id=NISX20190612_0000678058&amp;cID=10101&amp;pID=10100" onclick="return goOtherCR(this, 'a=nws*h.tit&amp;r=1&amp;i=88000127_000000000000000009280974&amp;g=003.0009280974&amp;u='+urlencode(this.href));" target="_blank" title='볼턴 "3차 북미정상회담 가능…열쇠는 김정은 손에"(종합)'>볼턴 "3차 북미<strong class="hl">정상회담</strong> 
# ...

# %%
len(now_ul)
# Out:
# 10

# %%
news_list=[]
count=0

for li in now_ul:
    news_dict={}
    a_tag=li.find('dl').find('dt').find('a')
    
    if count==0:
        print(a_tag, end='\n\n')
    count+=1
# Out:
# <a class="_sp_each_title" href="http://www.newsis.com/view/?id=NISX20190612_0000678058&amp;cID=10101&amp;pID=10100" onclick="return goOtherCR(this, 'a=nws*h.tit&amp;r=1&amp;i=88000127_000000000000000009280974&amp;g=003.0009280974&amp;u='+urlencode(this.href));" target="_blank" title='볼턴 "3차 북미정상회담 가능…열쇠는 김정은 손에"(종합)'>볼턴 "3차 북미<strong class="hl">정상회담</strong> 가능…열쇠는 김정은 손에"(종합)</a>
