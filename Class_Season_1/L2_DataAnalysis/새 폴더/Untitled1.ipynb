# %%
mkdir Html
# Out:
# 하위 디렉터리 또는 파일 Html이(가) 이미 있습니다.

# %%
# %%writefile 'Html/sample_html1.html'

html = '''<!doctype html> 
<html lang="en"> 
 <head>
    <meta charset='UTF-8'>
    <title>multicampus</title>
 </head>
 <body>
    <h1>
        <p>'파이썬'</p> 
    </h1>
    <h2>
        <p>'프로그래밍'</p> 
    </h2>
    <h3>
        <p>데이터분석</p> 
    </h3>
    <ul>
        <li>1</li>
        <li>2</li>
        <li>3</li>            
    </ul>
    
    <ol>
        <li>4</li>
        <li>5</li>
        <li>6</li>
    </ol>
    
    <table>
        <tr>
            <td>a</td>
            <td>b</td>
            <td>c</td>
        </tr>
        
        <tr>
            <td>d</td>
            <td>e</td>
            <td>f</td>
        </tr>
    
    </table>

    <table>    
        <thead>
            <tr>
                <th>a</th>
                <th>b</th>
                <th>c</th>
            </tr>
        </thead>
        <tbody>
            <tr>
                <td>1</td>
                <td>2</td>
                <td>3</td>
            </tr>
            <tr>
                <td>10</td>
                <td>20</td>
                <td>30</td>
            </tr>
        </tbody>
        
        <input type='text' value='input1'>
        <input type='text' value='input2'>
        <input type='text' value='input3'>
        
        <button>버튼1</button>
    </table>
    <table>
        <tr>
            <td><span>1</span></td>
            <td><span>2</span></td>
            <td><span>3</span></td>
        </tr>
        <tr>
            <td><span>4</span></td>
            <td><span>5</span></td>
            <td><span>6</span></td>
        </tr>
        <tr>
            <td><span>7</span></td>
            <td><span>8</span></td>
            <td><span>9</span></td>
        </tr>
    </table>  
    
    <span>내용</span>
    
    <a href='a'>a로이동</a>
    
 </body>
</html>'''
